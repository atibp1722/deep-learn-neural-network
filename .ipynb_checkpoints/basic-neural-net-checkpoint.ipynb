# %% [markdown]
# # using neural network to make prediction of whether patient has diabetes

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# %%
data=pd.read_csv('data/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import seaborn as sns

data['Outcome'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Outcome'>

# %% [markdown]
# # data processing

# %%
# split data into X and Y for input and output respectively

# everything except response is tkan into the predictor
predictors=data.iloc[:,0:8]
response=data.iloc[:,8]

# %%
# split data into train and test sets

X_train,y_train,X_test,y_test=train_test_split(predictors,response,test_size=0.3)
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (537, 8) (231, 8)
# (537,) (231,)

# %% [markdown]
# # training the neural network
#
# # sequential API allows to build keras model layer by layer

# %%
# defining the keras model

kerasmodel=Sequential()
# first hidden layer
# dense is full connected neural network layer
# 8 independent columns i.e. dimensions
kerasmodel.add(Dense(12,input_dim=8,activation='relu'))
# relu for avoiding extreme gradients at both ends
kerasmodel.add(Dense(8,activation='relu'))
# output layer; value ranges between 0 and 1
kerasmodel.add(Dense(1,activation='sigmoid'))

# %%
# compile model
kerasmodel.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# fit model
kerasmodel.fit(X_train,y_train,X_test,y_test,epochs=200,batch_size=10)
